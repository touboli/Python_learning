# %%
"""使用Python打开一个文本文件"""
f = open('test.txt','r',encoding = 'utf-8')  #打开文件，r表示以只读的方式打开文件
print(f.read())    #读取文件内容
f.close()  #关闭文件句柄
# Out:
# touboli12345

# %%
f = open("test.txt","r",encoding = "utf-8")
print(f.readline())  #读取一行
print(f.read(5))
f.close()

"""read()方法会读取文件的全部内容，并返回一个字符串
。如果你在调用read()方法之后再调用readline()方法，
readline()方法将会返回一个空字符串，因为read()方法
已经将文件指针移动到了文件的末尾。
readline()方法会读取文件的一行内容，并返回一个字符串。
\每次调用readline()方法，文件指针都会移动到下一行，
所以下一次调用readline()方法时，它将会返回下一行的内容。"""
# Out:
# touboli12345
#
# lidat
# 'read()方法会读取文件的全部内容，并返回一个字符串\n。如果你在调用read()方法之后再调用readline()方法，\nreadline()方法将会返回一个空字符串，因为read()方法\n已经将文件指针移动到了文件的末尾。\nreadline()方法会读取文件的一行内容，并返回一个字符串。\n\\每次调用readline()方法，文件指针都会移动到下一行，\n所以下一次调用readline()方法时，它将会返回下一行的内容。'

# %%
"""打开一个不存在的文件（使用只读模式）："""
f = open("t.txt","r",encoding = "utf-8")
f.read()
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 f = open("t.txt","r",encoding = "utf-8")
#       2 f.read()
#       3 f.close()
#
# File c:\Users\李博\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 't.txt'

# %%
"""写入内容到文本中"""
str_ = """南宋末年，金兵入侵，朝廷奸臣当道。全真派丘处机因杀死汉奸王道乾，被官兵追杀，逃到江南一个小村牛
家庄， 
与隐居在此处的爱国义土郭啸天和杨铁心一见如故，以“靖、康”为他俩即将出生的孩子命名，并留下一对
短剑作为信物。 
三人酒醉之后。杨妻包惜弱在外面忽然发现一个受伤的官兵，于是偷偷将其救下。 
哪知却为郭、杨两家带来无尽的灾难。原来，此人竟是金国六王子完颜洪烈，因为追杀丘处机被打伤，得包
惜弱相救后，竟然对她一见钟情， 
于是勾结南宋官员段天德对郭、杨迫害。郭啸天死亡、杨铁心不知去向，已怀身孕的郭夫人李萍被段天德抓
走，之后经过千辛万苦逃到大漠， 
生下儿子郭靖，而杨夫人包惜弱则被骗嫁给完颜洪烈，生子完颜康。丘处机得知两家被害的消息后，一路对
凶手进行追查， 
与江南七怪发生误会。双方不打不相识，定下赌约：分别寻找杨、郭的后人并传授他们武功，于十八年后在
醉仙楼比试高低。 """

f = open("test.txt","r+",encoding = "utf-8")  #以读写模式打开文件 ,r+表示读写模式,w表示写入模式
f.write(str_)
print(f.readline())
f.close()
# Out:
# 南宋末年，金兵入侵，朝廷奸臣当道。全真派丘处机因杀死汉奸王道乾，被官兵追杀，逃到江南一个小村牛

# %%
"""使用a模式写入文件"""
f = open("test.txt","a+",encoding = "utf-8")  #以追加读写模式打开文件
f.write("这是追加的内容")
print(f.readline())
f.close()

# %%
f=open("test.txt","a+",encoding = "utf-8")
print(f.readline())    #读取一行，因为文件指针已经移动到了文件的末尾，所以读取的是空字符串
f.close()

# %%
"""换个姿势读文件"""
f = open("test.txt","r",encoding = "utf-8")
line = f.readline() 
lines = f.readlines() 
print(line) 
print(lines)
# Out:
# 南宋末年，金兵入侵，朝廷奸臣当道。全真派丘处机因杀死汉奸王道乾，被官兵追杀，逃到江南一个小村牛
#
# ...

# %%
#写入文件不关闭的后果 
str_ = """ -- 射雕英雄传/金庸 
""" 
f = open("text_new.txt", "a", encoding="utf8") 
f.write(str_) 
# 此处不适用close关闭文件 
#读取这个没保存的文件： 
f_new = open("text_new.txt", "r", encoding="utf8") 
f_new.read() 
# 输出为空

# %%
"""使用flush()方法强制将缓冲区的数据写入文件"""
str_ = """ 
-- 射雕英雄传/金庸
"""
f = open("test_new.txt", "a", encoding="utf8")
f.write(str_)
f.flush()
f_new = open("test_new.txt", "r", encoding="utf8")
print(f_new.read())
# Out:
#
# -- 射雕英雄传/金庸

# %%
"""文件操作函数"""
f= open("test.txt","r",encoding = "utf-8")
a = f.read(12)  #读取10个字符
f.tell()  #返回文件指针的当前位置
# Out:
# 36

# %%
"""上下文管理器"""
with open("test.txt","a",encoding = "utf-8") as f:
    f.write("这小说真好看个鬼")

with open("test.txt","r",encoding = "utf-8") as f:
    print(f.read())
# Out:
# 南宋末年，金兵入侵，朝廷奸臣当道。全真派丘处机因杀死汉奸王道乾，被官兵追杀，逃到江南一个小村牛
# 家庄，
# 与隐居在此处的爱国义土郭啸天和杨铁心一见如故，以“靖、康”为他俩即将出生的孩子命名，并留下一对
# 短剑作为信物。
# 三人酒醉之后。杨妻包惜弱在外面忽然发现一个受伤的官兵，于是偷偷将其救下。
# 哪知却为郭、杨两家带来无尽的灾难。原来，此人竟是金国六王子完颜洪烈，因为追杀丘处机被打伤，得包
# 惜弱相救后，竟然对她一见钟情，
# 于是勾结南宋官员段天德对郭、杨迫害。郭啸天死亡、杨铁心不知去向，已怀身孕的郭夫人李萍被段天德抓
# 走，之后经过千辛万苦逃到大漠，
# 生下儿子郭靖，而杨夫人包惜弱则被骗嫁给完颜洪烈，生子完颜康。丘处机得知两家被害的消息后，一路对
# 凶手进行追查，
# 与江南七怪发生误会。双方不打不相识，定下赌约：分别寻找杨、郭的后人并传授他们武功，于十八年后在
# 醉仙楼比试高低。 南宋末年，金兵入侵，朝廷奸臣当道。全真派丘处机因杀死汉奸王道乾，被官兵追杀，逃到江南一个小村牛
# 家庄，
# 与隐居在此处的爱国义土郭啸天和杨铁心一见如故，以“靖、康”为他俩即将出生的孩子命名，并留下一对
# 短剑作为信物。
# 三人酒醉之后。杨妻包惜弱在外面忽然发现一个受伤的官兵，于是偷偷将其救下。
# 哪知却为郭、杨两家带来无尽的灾难。原来，此人竟是金国六王子完颜洪烈，因为追杀丘处机被打伤，得包
# 惜弱相救后，竟然对她一见钟情，
# 于是勾结南宋官员段天德对郭、杨迫害。郭啸天死亡、杨铁心不知去向，已怀身孕的郭夫人李萍被段天德抓
# 走，之后经过千辛万苦逃到大漠，
# 生下儿子郭靖，而杨夫人包惜弱则被骗嫁给完颜洪烈，生子完颜康。丘处机得知两家被害的消息后，一路对
# 凶手进行追查，
# 与江南七怪发生误会。双方不打不相识，定下赌约：分别寻找杨、郭的后人并传授他们武功，于十八年后在
# 醉仙楼比试高低。 南宋末年，金兵入侵，朝廷奸臣当道。全真派丘处机因杀死汉奸王道乾，被官兵追杀，逃到江南一个小村牛
# 家庄，
# 与隐居在此处的爱国义土郭啸天和杨铁心一见如故，以“靖、康”为他俩即将出生的孩子命名，并留下一对
# 短剑作为信物。
# 三人酒醉之后。杨妻包惜弱在外面忽然发现一个受伤的官兵，于是偷偷将其救下。
# ...

# %%
"""使用Python读取其他数据文件"""
"""读取图片文件"""
with open("小埋.jpg","r",encoding='utf8') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 4
#       2 """读取图片文件"""
#       3 with open("小埋.jpg","r",encoding='utf8') as f:
# ----> 4     print(f.read())
#
# File c:\Users\李博\AppData\Local\Programs\Python\Python38\lib\codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
with open("小埋.jpg","rb") as f:
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x01h\x01h\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\
# ...

# %%
"""获取图片的像素矩阵"""
import cv2
img = cv2.imread("xuerongrong.png")   #读取图片，但不支持jpg格式
print(img)
# Out:
# [[[200 200 200]
#   [236 236 236]
#   [236 236 236]
#   ...
#   [236 236 236]
#   [236 236 236]
#   [236 236 236]]
#
#  [[208 208 208]
#   [240 240 240]
#   [239 239 239]
#   ...
#   [239 239 239]
#   [239 239 239]
#   [239 239 239]]
#
#  [[208 208 208]
#   [240 240 240]
#   [239 239 239]
#   ...
#   [239 239 239]
#   [239 239 239]
#   [239 239 239]]
#
#  ...
#
#  [[208 208 208]
#   [242 242 242]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[208 208 208]
#   [242 242 242]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[208 208 208]
#   [242 242 242]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]]

# %%
"""读取音频文件"""
with open("music.wav", "rb") as f: 
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 """读取音频文件"""
# ----> 2 with open("music.wav", "rb") as f:
#       3     print(f.read())
#
# File c:\Users\李博\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'music.wav'

# %%
""" 获取音频的矩阵表示  """
from scipy.io import wavfile 
wav_data = wavfile.read("music.wav") 
wav_data

# %%
""" 读取csv文件  """
import pandas as pd 
df = pd.read_csv("air.csv", names=["城市","PM2.5","等级"], encoding="GBK") 
df
